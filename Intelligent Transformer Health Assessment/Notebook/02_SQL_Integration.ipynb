# %%
import pandas as pd 
import psycopg2
from sqlalchemy import create_engine

# %%
df = pd.read_csv("../Data/Health_index_final.csv")
df.head()
# Out:
#   Transformer_ID  Hydrogen  Oxigen  Nitrogen  Methane   CO   CO2  Ethylene  \
# 0           TX_1      2845    5860     27842     7406   32  1344     16684
# 1           TX_2     12886      61     25041      877   83   864         4
# 2           TX_3      2820   16400     56300      144  257  1080       206
# 3           TX_4      1099      70     37520      545  184  1402         6
# 4           TX_5      3210    3570     47900      160  360  2130         4
#
#    Ethane  Acethylene  DBDS  Power factor  Interfacial V  Dielectric rigidity  \
# 0    5467           7  19.0          1.00             45                   55
# 1     305           0  45.0          1.00             45                   55
# 2      11        2190   1.0          1.00             39                   52
# 3     230           0  87.0          4.58             33                   49
# 4      43           4   1.0          0.77             44                   55
#
#    Water content  Health index Health_Category
# 0              0          30.0            Poor
# 1              0          30.0            Poor
# 2             11          30.0            Poor
# 3              5          58.4            Fair
# 4              3          60.0            Fair

# %%
engine = create_engine("postgresql://postgres:Shivam@localhost:5432/transformer_monitoring")

# %%
df.to_sql(name='transformer_data', con=engine, if_exists='replace', index=False)
# Out:
# 470
